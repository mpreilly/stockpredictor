# %%
import pandas as pd

COLUMNS = ['Stock', 'Closing Price', 'Percent Change', 'Volume', 'PEG Ratio',
            'Short Ratio', 'Pct Change from Year High', 'Pct Change from Year Low',
            'Pct Change from 50 day Moving Avg', 'Ratio to Target', 'Stochastic Oscillator']

df_train = pd.read_csv('data/training_1day_data.csv', names=COLUMNS)
df_test = pd.read_csv('data/testing_1day_data.csv', names=COLUMNS)

# %%
pd.read_csv('data/training_1day_data.csv', names=COLUMNS, skiprows=1)
# Out:
#      Stock  Closing Price  Percent Change   Volume  PEG Ratio  Short Ratio  \
# 0     PRSC        41.3800         -1.4100    35479       1.66         3.90
# 1     CYTK        11.8500          2.6000   520277      -0.36        11.02
# 2      GPP        20.0000          0.7600    70316       0.69         0.31
# 3     PRQR         4.3750          4.1670   118305       0.00         4.73
# 4     CDTX         7.0500         -1.4000    68927       0.00         6.49
# 5     GNMX         4.8600          2.3200   300346       0.00         4.78
# 6     PGTI        10.1500         -1.4600   238752       0.59         7.24
# 7      EXA        15.3900         -2.7200    23484       0.00         5.53
# 8     TCMD        19.0000          0.2600    51967       9.24         4.39
# 9     BRKR        23.7100         -2.9900   776074       2.43         5.02
# 10    CASM         1.4500         -2.6800    42105      -0.50         0.09
# ...

# %%
pd.read_csv('data/training_1day_nextdaychanges.csv', names=('next day pct change',))
# Out:
# ---------------------------------------------------------------------------
# CParserError                              Traceback (most recent call last)
# <ipython-input-21-3be49b539d96> in <module>()
# ----> 1 pd.read_csv('data/training_1day_nextdaychanges.csv', names='next day pct change')
#
# ...
